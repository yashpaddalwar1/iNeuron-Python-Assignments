# %% [markdown]
# # *Author: Yash Ajit Paddalwar*
# # *Email ID: yash9096.p@gmail.com*

# %% [markdown]
# **1. Write a function that takes a positive integer num and calculates how many dots exist in a pentagonal shape around the center dot on the Nth iteration. In the image below you can see the first iteration is only a single dot. On the second, there are 6 dots. On the third, there are 16 dots, and on the fourth there are 31 dots.**
#
# Return the number of dots that exist in the whole pentagon on the Nth iteration.
# Examples
# pentagonal(1) ➞ 1
#
# pentagonal(2) ➞ 6
#
# pentagonal(3) ➞ 16
#
# pentagonal(8) ➞ 141

# %% [markdown]
# ![](ass2.png)
# **Solution**

# %%
def pentagon(n):
    return int((5*(n**2) - 5*n + 2)/2)

pentagon(10)
# Out:
# 226

# %% [markdown]
# ![](1.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# **Solution**

# %%
def encrypt(Input):
    # Reversing the Input
    rev = Input[::-1]

    # Replacing the Vowels
    Vowels = {'a':'0','e':'1','i':'2','o':'2','u':'3'}
    Final_Encrypted_String = ""
    for i in list(rev):
        if i in Vowels:
            Final_Encrypted_String += (Vowels[i])
        else:
            Final_Encrypted_String += (i)

    # Adding 'aca' string at the last
    Final_Encrypted_String += 'aca'

    # Printing the final Encrypted String
    return (Final_Encrypted_String)

# Calling the Function
encrypt("banana")
# Out:
# '0n0n0baca'

# %% [markdown]
# ![image.png](attachment:image.png)
# **Solution**

# %%
# Importing the Datetime Module
import datetime as dt

# Function to check the condition
def has_friday_13(month,year):
    month,year = str(month),str(year)
    
    if dt.datetime.strptime('13 ' + ' ' + month + ' ' + year, '%d %m %Y').weekday() == 4:
        return True
    else:
        return False
    
has_friday_13(3,2020)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)
# **Solution**

# %%
import re

lst = ["bad cookie", "good cookie", "bad cookie", "good cookie", "good cookie"]
pattern = "bad cookie";
len(re.findall(pattern, ",".join(lst)))
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# **Solution**

# %%
lst = []
final_set = {}
def pluralize(n):
    for i in n:
        if (len(re.findall(i,",".join(n)))) > 1:
            m = i + 's'
            lst.append(m)
        else:
            lst.append(i)
    final_set = set(lst)
    return final_set

# Calling the Function
pluralize(["cow","pig","cow","cow"])
# Out:
# {'cows', 'pig'}
